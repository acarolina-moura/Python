# %%
# Created DataFrame

import pandas as pd

df1 = pd.DataFrame({
    'name': ['Ana', 'Clara', 'Maria'],
    'age': [28, 22, 45],
    'addres': ['Portugal', 'Brasil', 'Espanha']
})

print(df1)
# Out:
#     name  age    addres
# 0    Ana   28  Portugal
# 1  Clara   22    Brasil
# 2  Maria   45   Espanha

# %%
df2 = pd.DataFrame([
  [1, 'San Diego', 100],
  [2, 'Los Angeles', 120],
  [3, 'San Francisco', 90],
  [4, 'Sacramento',115]
],
                   
# Addd columns witch "COLUMNS COMMAND"
  columns=['Store ID','Location', 'Number of Employees'])

print(df2)
# Out:
#    Store ID       Location  Number of Employees
# 0         1      San Diego                  100
# 1         2    Los Angeles                  120
# 2         3  San Francisco                   90
# 3         4     Sacramento                  115
