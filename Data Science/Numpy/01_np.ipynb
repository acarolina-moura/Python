# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([2010, 2015])
ypoints = np.array([1000, 1500])

plt.plot(xpoints,ypoints)
plt.show()

# %%
eixo_X_dias= [1,5,10,15,20,25,30]
eixo_y_temp_max = [28,29,25,32,34,36,31]

plt.plot(eixo_X_dias,eixo_y_temp_max)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

X_dias= [1,5,10,15,20,25,30]
y_tickets = [28,29,25,32,34,36,31]

plt.plot(X_dias, y_tickets)
plt.show()
