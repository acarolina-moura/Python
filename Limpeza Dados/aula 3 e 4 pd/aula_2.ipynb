# %%
import pandas as pd

df_movies = pd.read_excel("Movies.xlsx")

df_movies.head(10)
# Out:
#    ID                                      Title Release Date  Run Time  \
# 0   1                              Jurassic Park   1993-06-11       126
# 1   2                                 Spider-Man   2002-05-03       121
# 2   3                                  King Kong   2005-12-14       187
# 3   5                           Superman Returns   2006-07-14       154
# 4   6                                    Titanic   1998-01-23       194
# 5   7                              Evan Almighty   2007-06-22        96
# 6   8                                 Waterworld   1995-07-28       135
# 7   9                               Pearl Harbor   2001-05-21       183
# 8  10                               Transformers   2007-07-03       144
# 9  11  Harry Potter and the Order of the Phoenix   2007-07-11       138
#
#              Genre          Director                   Studio         Country  \
# 0        Adventure  Steven Spielberg     Amblin Entertainment   United States
# ...

# %%
df_movies.tail(2)
# Out:
#         ID                Title Release Date  Run Time     Genre  \
# 1198  1677  In the Line of Fire   1993-07-09       128  Thriller
# 1199  1678             Outbreak   1995-03-10       128  Thriller
#
#                Director                     Studio        Country Language  \
# 1198  Wolfgang Peterson  Castle Rock Entertainment  United States  English
# 1199  Wolfgang Peterson      Warner Bros. Pictures  United States  English
#
#      Certificate      Budget   Box Office  Nominations  Oscar Wins
# 1198          15  40000000.0  177000000.0            3           0
# 1199          15  50000000.0  189800000.0            0           0

# %%
df_movies.info()
