# %%
import numpy as np

vetor = np.array ([2,4,6,8,10])
print(vetor)
# Out:
# [ 2  4  6  8 10]

# %%
matriz = np.array ([[2, 4], [1, 3], [1 , 2]])
print(matriz)
# Out:
# [[2 4]
#  [1 3]
#  [1 2]]

# %%
intervalo = np.arange (0, 10, 2)
print(intervalo)
# Out:
# [0 2 4 6 8]
