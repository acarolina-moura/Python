# %%
import numpy as np

notas = np.array([7.5, 8.0, 6.5, 9.0, 5.5])

media = np.mean(notas)
print(media)
mediana = np.median(notas)
print(mediana)
desvio = np.std(notas)

notas_acima_media = notas [notas > media]
print(notas_acima_media)
# Out:
# 7.3
# 7.5
# [7.5 8.  9. ]
